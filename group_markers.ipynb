# %%
from sctoolbox.utils.jupyter import bgcolor, _compare_version

# change the background of input cells
bgcolor("PowderBlue", select=[2, 4, 6, 8, 16, 20])

nb_name = "group_markers.ipynb"

_compare_version(nb_name)
# Out:
# <img src onerror="
#                     // get all code cells
#                     let all_cells = document.querySelectorAll('.code_cell,.jp-CodeCell')
#                     // define the cell selection
#                     let selection = Array(2,4,6,8,16,20);
#                     // select the cells
#                     let sel_cells = selection.map(x=>all_cells[x]);
#                     // select the parts of the cells that should be colored (code area)
#                     let ca = sel_cells.map(e=>Array.from(e.querySelectorAll('.CodeMirror-sizer,.highlight'))).flat();
#                     // change the background color of all selected elements
#                     ca.forEach(e=>e.style.background='PowderBlue');
#                     " style="display:none">

# %% [markdown]
# # Marker computation and analysis
# <hr style="border:2px solid black"> </hr>
#
# ## 1 - Description
#
# **Note: Requires the dataset to be split into groups/ clusters. This can be achieved using a clustering notebook e.g. `04_clustering.ipynb` for RNA.**
#
# **Move this notebook into the notebook folder (e.g. `rna_analysis/notebooks/`) of the respective analysis before using it!**
#
# An important part of most analysis is the identification and subsequent interpretation of changes between predefined groups. Most commonly, groups were based on experimental conditions (e.g. healthy vs. ill) with the aim of identifying differential features (e.g. genes) to explain the underlying mechanisms. With the increased resolution of single cell data another approach became viable, namely the identification of cell types. But before cell type assignment (see  `annotation.ipynb`) markers have to be identified which follows the same concept of identifying group specific differences.
#
# This notebook is aimed at computing lists of potential markers, e.g. marker genes for RNA and marker peaks for ATAC, based on the selected groups and reviewing their performance through visualization. Two different methods are provided for the identification of group markers:
#
# - The [rank_genes_groups()](https://scanpy.readthedocs.io/en/stable/generated/scanpy.tl.rank_genes_groups.html) method from scanpy.
# - [DESeq2](https://doi.org/doi:10.18129/B9.bioc.DESeq2) a method originally intended for bulk that will be run by first creating pseudobulks from the given groups.

# %% [markdown]
# ---------

# %% [markdown]
# ## 2 - Loading packages

# %%
import scanpy as sc
import pandas as pd
import numpy as np
import matplotlib.backends.backend_pdf

import sctoolbox
import sctoolbox.utils as utils
import sctoolbox.tools as tools
import sctoolbox.plotting as pl
from sctoolbox import settings

# %% [markdown]
# ---------

# %% [markdown]
# ## 3 - Loading adata

# %% [markdown]
# <h1><center>⬐ Fill in input data here ⬎</center></h1>

# %%
# sctoolbox settings
settings.adata_input_dir = "../adatas/"
settings.adata_output_dir = "../adatas/"
settings.figure_dir = "../figures/markers/"
settings.table_dir = "../tables/markers/"
settings.log_file = "../logs/marker_log.txt"
settings.overwrite_log = True

anndata_file = "anndata_4.h5ad"
# Out:
# Created directory: ../figures/markers/
# Created directory: ../tables/markers/
# [WARNING] Log file '../logs/marker_log.txt' already exists. The file will be overwritten since 'overwrite_log' is set to True.

# %% [markdown]
# ___

# %%
adata = utils.adata.load_h5ad(anndata_file)

with pd.option_context("display.max.rows", 5, "display.max.columns", None):
    display(adata)
    display(adata.obs)
# Out:
# [INFO] The adata object was loaded from: ../adatas/anndata_4.h5ad
# AnnData object with n_obs × n_vars = 3344 × 57031
#     obs: 'TubeID', 'meta_TubeID', 'meta_pop_export_psn', 'meta_pop_visit_1_date', 'meta_pop_visit_2_date', 'meta_pop_visit_3_date', 'meta_pop_visit_4_date', 'meta_pop_age', 'meta_pop_age_dec', 'meta_pop_sex', 'meta_pop_c19_severity', 'meta_pop_cohort', 'meta_suep_hap_export_psn', 'meta_suep_hap_baseline_date', 'meta_suep_hap_end_acute_date', 'meta_suep_hap_end_acute_visit_date', 'meta_suep_hap_m3_fu_date', 'meta_suep_hap_m6_fu_date', 'meta_suep_hap_m12_fu_date', 'meta_suep_hap_m24_fu_date', 'meta_suep_hap_age', 'meta_suep_hap_age_dec', 'meta_suep_hap_sex', 'meta_suep_hap_c19_severity', 'meta_suep_hap_cohort', 'meta_export_psn', 'meta_age', 'meta_age_dec', 'meta_sex', 'meta_c19_severity', 'meta_cohort', 'rna_TubeID', 'rna_id', 'rna_fastq1', 'rna_project', 'rna_run', 'rna_plate', 'rna_organism', 'rna_assembly', 'rna_release', 'rna_parameters', 'rna_reads_processed', 'rna_reads_with_exactly_1_alignment', 'rna_reads_with_multiple_alignments', 'rna_reads_with_no_alignment', 'rna_reads_aligned', 'rna_pct_reads_aligned', 'rna_duplicate_reads', 'rna_pct_duplicate_reads', 'rna_mitochondrial_reads', 'rna_pct_mitochondrial_reads', 'rna_rrna_subunit_reads', 'rna_pct_rrna_subunit_reads', 'rna_pcr_bottleneck_coefficient', 'rna_mean_fragment_size_(only_for_paired-end)', 'rna_reads_used_after_filters', 'rna_parameters.1', 'rna_reads_processed.1', 'rna_reads_assigned', 'rna_pct_reads_assigned_total', 'rna_pct_features_with_cpm_at_least_0.5', 'rna_unass._reads_overlapping_multiple_genes', 'rna_unass._reads_mapping_to_multiple_locations', 'rna_unass._reads_mapping_to_no_feature', 'rna_unass._reads_not_mapping', 'rna_unass._reads__bad_mapping_quality', 'rna_unass._reads__low_fragment_length', 'rna_unass._chimeric_reads', 'mapped_reads_over_2000000', 'rna_DDX3Y', 'rna_XIST', 'rna_gender', 'rna_sample_id_original', 'rna_plate_id_original', 'filename', 'rel_path', 'n_genes', 'log1p_n_genes', 'total_counts', 'log1p_total_counts', 'total_counts_is_mito', 'log1p_total_counts_is_mito', 'pct_counts_is_mito', 'total_counts_is_ribo', 'log1p_total_counts_is_ribo', 'pct_counts_is_ribo', 'total_counts_is_gender', 'log1p_total_counts_is_gender', 'pct_counts_is_gender', 'S_score', 'G2M_score', 'phase', 'leiden', 'LISI_score_X_pca', 'LISI_score_X_umap', 'phase_density', 'meta_age_dec_density', 'leiden_0.1', 'leiden_0.2', 'leiden_0.3', 'leiden_0.4', 'leiden_0.5', 'leiden_0.6', 'leiden_0.7', 'leiden_0.8', 'leiden_0.9', 'clustering'
#     var: 'Ensembl_gene_id', 'Ensembl_biotype', 'UniProt_proteins', 'UniProt_genes', 'UniProt_accessions', 'UniProt_names', 'UniProt_Ensembl_transcripts', 'UniProt_Ensembl_proteins', 'UniProt_Ensembl_gene_ids', 'Ensembl_chr', 'Ensembl_start', 'Ensembl_stop', 'Ensembl_strand', 'KEGG_PATHWAY_terms', 'KEGG_PATHWAY_ids', 'Gene_Ontology_terms', 'Gene_Ontology_ids', 'is_mito', 'is_ribo', 'is_gender', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'clustering_colors', 'hvg', 'leiden', 'leiden_0.1', 'leiden_0.1_colors', 'leiden_0.2', 'leiden_0.2_colors', 'leiden_0.3', 'leiden_0.3_colors', 'leiden_0.4', 'leiden_0.4_colors', 'leiden_0.5', 'leiden_0.5_colors', 'leiden_0.6', 'leiden_0.6_colors', 'leiden_0.7', 'leiden_0.7_colors', 'leiden_0.8', 'leiden_0.8_colors', 'leiden_0.9', 'leiden_0.9_colors', 'leiden_colors', 'log1p', 'meta_age_dec_colors', 'meta_age_dec_density_params', 'meta_c19_severity_colors', 'meta_sex_colors', 'neighbors', 'pca', 'phase_colors', 'phase_density_params', 'rna_plate_colors', 'sctoolbox', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'raw'
#     obsp: 'connectivities', 'distances'
#                            TubeID   meta_TubeID meta_pop_export_psn  \
# rna project.run id
# plt1.run1 pat_88     LV1007699778  LV1007699778                   0
# plt1.run1 pat_89     LV1007699743  LV1007699743                   0
# ...                           ...           ...                 ...
# plt49.run1 pat_3571             0             0                   0
# plt49.run1 pat_3572             0             0                   0
#
#                     meta_pop_visit_1_date meta_pop_visit_2_date  \
# rna project.run id
# plt1.run1 pat_88                        0                     0
# plt1.run1 pat_89                        0                     0
# ...                                   ...                   ...
# plt49.run1 pat_3571                     0                     0
# plt49.run1 pat_3572                     0                     0
#
#                     meta_pop_visit_3_date meta_pop_visit_4_date  meta_pop_age  \
# rna project.run id
# plt1.run1 pat_88                        0                     0           0.0
# plt1.run1 pat_89                        0                     0           0.0
# ...                                   ...                   ...           ...
# plt49.run1 pat_3571                     0                     0           0.0
# plt49.run1 pat_3572                     0                     0           0.0
#
#                     meta_pop_age_dec meta_pop_sex meta_pop_c19_severity  \
# rna project.run id
# plt1.run1 pat_88                   0            0                     0
# plt1.run1 pat_89                   0            0                     0
# ...                              ...          ...                   ...
# plt49.run1 pat_3571                0            0                     0
# plt49.run1 pat_3572                0            0                     0
#
#                     meta_pop_cohort meta_suep_hap_export_psn  \
# rna project.run id
# plt1.run1 pat_88                  0                 hap_0178
# plt1.run1 pat_89                  0                suep_0425
# ...                             ...                      ...
# plt49.run1 pat_3571               0                        0
# plt49.run1 pat_3572               0                        0
#
#                     meta_suep_hap_baseline_date meta_suep_hap_end_acute_date  \
# rna project.run id
# plt1.run1 pat_88                     17/11/2021                   24/11/2021
# plt1.run1 pat_89                     08/11/2021                   17/11/2021
# ...                                         ...                          ...
# plt49.run1 pat_3571                           0                            0
# plt49.run1 pat_3572                           0                            0
#
#                     meta_suep_hap_end_acute_visit_date  \
# rna project.run id
# plt1.run1 pat_88                            24/11/2021
# plt1.run1 pat_89                            17/11/2021
# ...                                                ...
# plt49.run1 pat_3571                                  0
# plt49.run1 pat_3572                                  0
#
#                     meta_suep_hap_m3_fu_date meta_suep_hap_m6_fu_date  \
# rna project.run id
# plt1.run1 pat_88                           0                        0
# plt1.run1 pat_89                           0                        0
# ...                                      ...                      ...
# plt49.run1 pat_3571                        0                        0
# plt49.run1 pat_3572                        0                        0
#
#                     meta_suep_hap_m12_fu_date meta_suep_hap_m24_fu_date  \
# rna project.run id
# plt1.run1 pat_88                            0                         0
# plt1.run1 pat_89                            0                         0
# ...                                       ...                       ...
# plt49.run1 pat_3571                         0                         0
# plt49.run1 pat_3572                         0                         0
#
#                      meta_suep_hap_age meta_suep_hap_age_dec  \
# rna project.run id
# plt1.run1 pat_88                  65.0                 60-69
# plt1.run1 pat_89                  61.0                 60-69
# ...                                ...                   ...
# plt49.run1 pat_3571                0.0                     0
# plt49.run1 pat_3572                0.0                     0
#
#                     meta_suep_hap_sex meta_suep_hap_c19_severity  \
# rna project.run id
# plt1.run1 pat_88                    M                     severe
# plt1.run1 pat_89                    M                       mild
# ...                               ...                        ...
# plt49.run1 pat_3571                 0                          0
# plt49.run1 pat_3572                 0                          0
#
#                     meta_suep_hap_cohort meta_export_psn  meta_age  \
# rna project.run id
# plt1.run1 pat_88                     hap        hap_0178      65.0
# plt1.run1 pat_89                    suep       suep_0425      61.0
# ...                                  ...             ...       ...
# plt49.run1 pat_3571                    0               0       0.0
# plt49.run1 pat_3572                    0               0       0.0
#
#                     meta_age_dec meta_sex meta_c19_severity meta_cohort  \
# rna project.run id
# plt1.run1 pat_88           60-69        M            severe         hap
# plt1.run1 pat_89           60-69        M              mild        suep
# ...                          ...      ...               ...         ...
# plt49.run1 pat_3571            0        0                 0           0
# plt49.run1 pat_3572            0        0                 0           0
#
#                        rna_TubeID  rna_id  \
# rna project.run id
# plt1.run1 pat_88     LV1007699778  pat_88
# plt1.run1 pat_89     LV1007699743  pat_89
# ...                           ...     ...
# plt49.run1 pat_3571             0       0
# plt49.run1 pat_3572             0       0
#
#                                                             rna_fastq1  \
# rna project.run id
# plt1.run1 pat_88     AAAVY52HV_NAPKON_Plate1_2_22s004137-1-1_Valasa...
# plt1.run1 pat_89     AAAVY52HV_NAPKON_Plate1_2_22s004137-1-1_Valasa...
# ...                                                                ...
# plt49.run1 pat_3571                                                  0
# plt49.run1 pat_3572                                                  0
#
#                     rna_project rna_run rna_plate rna_organism rna_assembly  \
# rna project.run id
# plt1.run1 pat_88           plt1    run1    plate1        human         hg38
# plt1.run1 pat_89           plt1    run1    plate1        human         hg38
# ...                         ...     ...       ...          ...          ...
# plt49.run1 pat_3571           0       0         0            0            0
# plt49.run1 pat_3572           0       0         0            0            0
#
#                      rna_release  \
# rna project.run id
# plt1.run1 pat_88           104.0
# plt1.run1 pat_89           104.0
# ...                          ...
# plt49.run1 pat_3571          0.0
# plt49.run1 pat_3572          0.0
#
#                                                         rna_parameters  \
# rna project.run id
# plt1.run1 pat_88     mode: single-end, keep duplicates: no, keep mu...
# plt1.run1 pat_89     mode: single-end, keep duplicates: no, keep mu...
# ...                                                                ...
# plt49.run1 pat_3571                                                  0
# plt49.run1 pat_3572                                                  0
#
#                     rna_reads_processed rna_reads_with_exactly_1_alignment  \
# rna project.run id
# plt1.run1 pat_88             29,112,743                         23,152,813
# plt1.run1 pat_89             24,355,220                         13,253,462
# ...                                 ...                                ...
# plt49.run1 pat_3571                   0                                  0
# plt49.run1 pat_3572                   0                                  0
#
#                     rna_reads_with_multiple_alignments  \
# rna project.run id
# plt1.run1 pat_88                             4,044,454
# plt1.run1 pat_89                             7,713,379
# ...                                                ...
# plt49.run1 pat_3571                                  0
# plt49.run1 pat_3572                                  0
#
#                     rna_reads_with_no_alignment rna_reads_aligned  \
# rna project.run id
# plt1.run1 pat_88                      1,915,476        27,197,267
# plt1.run1 pat_89                      3,388,379        20,966,841
# ...                                         ...               ...
# plt49.run1 pat_3571                           0                 0
# plt49.run1 pat_3572                           0                 0
#
#                      rna_pct_reads_aligned rna_duplicate_reads  \
# rna project.run id
# plt1.run1 pat_88                      93.0          20,093,139
# plt1.run1 pat_89                      86.0          17,678,467
# ...                                    ...                 ...
# plt49.run1 pat_3571                    0.0                   0
# plt49.run1 pat_3572                    0.0                   0
#
#                      rna_pct_duplicate_reads rna_mitochondrial_reads  \
# rna project.run id
# plt1.run1 pat_88                        73.0               1,714,158
# plt1.run1 pat_89                        84.0               1,475,002
# ...                                      ...                     ...
# plt49.run1 pat_3571                      0.0                       0
# plt49.run1 pat_3572                      0.0                       0
#
#                      rna_pct_mitochondrial_reads rna_rrna_subunit_reads  \
# rna project.run id
# plt1.run1 pat_88                             6.0              1,868,907
# plt1.run1 pat_89                             7.0              6,372,269
# ...                                          ...                    ...
# plt49.run1 pat_3571                          0.0                      0
# plt49.run1 pat_3572                          0.0                      0
#
#                      rna_pct_rrna_subunit_reads  \
# rna project.run id
# plt1.run1 pat_88                            6.0
# plt1.run1 pat_89                           30.0
# ...                                         ...
# plt49.run1 pat_3571                         0.0
# plt49.run1 pat_3572                         0.0
#
#                      rna_pcr_bottleneck_coefficient  \
# rna project.run id
# plt1.run1 pat_88                               0.28
# plt1.run1 pat_89                               0.22
# ...                                             ...
# plt49.run1 pat_3571                            0.00
# plt49.run1 pat_3572                            0.00
#
#                      rna_mean_fragment_size_(only_for_paired-end)  \
# rna project.run id
# plt1.run1 pat_88                                              0.0
# plt1.run1 pat_89                                              0.0
# ...                                                           ...
# plt49.run1 pat_3571                                           0.0
# plt49.run1 pat_3572                                           0.0
#
#                     rna_reads_used_after_filters  \
# rna project.run id
# plt1.run1 pat_88                       6,644,895
# plt1.run1 pat_89                       2,989,995
# ...                                          ...
# plt49.run1 pat_3571                            0
# plt49.run1 pat_3572                            0
#
#                                                       rna_parameters.1  \
# rna project.run id
# plt1.run1 pat_88     -t exon -g gene_id -s 2; multi-mapping: no; du...
# plt1.run1 pat_89     -t exon -g gene_id -s 2; multi-mapping: no; du...
# ...                                                                ...
# plt49.run1 pat_3571                                                  0
# plt49.run1 pat_3572                                                  0
#
#                     rna_reads_processed.1 rna_reads_assigned  \
# rna project.run id
# plt1.run1 pat_88                6,644,895          4,810,861
# plt1.run1 pat_89                2,989,995          2,155,768
# ...                                   ...                ...
# plt49.run1 pat_3571                     0                  0
# plt49.run1 pat_3572                     0                  0
#
#                      rna_pct_reads_assigned_total  \
# rna project.run id
# plt1.run1 pat_88                             16.0
# plt1.run1 pat_89                              8.0
# ...                                           ...
# plt49.run1 pat_3571                           0.0
# plt49.run1 pat_3572                           0.0
#
#                      rna_pct_features_with_cpm_at_least_0.5  \
# rna project.run id
# plt1.run1 pat_88                                       49.0
# plt1.run1 pat_89                                       45.0
# ...                                                     ...
# plt49.run1 pat_3571                                     0.0
# plt49.run1 pat_3572                                     0.0
#
#                      rna_unass._reads_overlapping_multiple_genes  \
# rna project.run id
# plt1.run1 pat_88                                         216.360
# plt1.run1 pat_89                                          97.961
# ...                                                          ...
# plt49.run1 pat_3571                                        0.000
# plt49.run1 pat_3572                                        0.000
#
#                      rna_unass._reads_mapping_to_multiple_locations  \
# rna project.run id
# plt1.run1 pat_88                                                0.0
# plt1.run1 pat_89                                                0.0
# ...                                                             ...
# plt49.run1 pat_3571                                             0.0
# plt49.run1 pat_3572                                             0.0
#
#                     rna_unass._reads_mapping_to_no_feature  \
# rna project.run id
# plt1.run1 pat_88                                 1,617,674
# plt1.run1 pat_89                                   736,266
# ...                                                    ...
# plt49.run1 pat_3571                                      0
# plt49.run1 pat_3572                                      0
#
#                      rna_unass._reads_not_mapping  \
# rna project.run id
# plt1.run1 pat_88                              0.0
# plt1.run1 pat_89                              0.0
# ...                                           ...
# plt49.run1 pat_3571                           0.0
# plt49.run1 pat_3572                           0.0
#
#                      rna_unass._reads__bad_mapping_quality  \
# rna project.run id
# plt1.run1 pat_88                                       0.0
# plt1.run1 pat_89                                       0.0
# ...                                                    ...
# plt49.run1 pat_3571                                    0.0
# plt49.run1 pat_3572                                    0.0
#
#                      rna_unass._reads__low_fragment_length  \
# rna project.run id
# plt1.run1 pat_88                                       0.0
# plt1.run1 pat_89                                       0.0
# ...                                                    ...
# plt49.run1 pat_3571                                    0.0
# plt49.run1 pat_3572                                    0.0
#
#                      rna_unass._chimeric_reads mapped_reads_over_2000000  \
# rna project.run id
# plt1.run1 pat_88                           0.0                      True
# plt1.run1 pat_89                           0.0                      True
# ...                                        ...                       ...
# plt49.run1 pat_3571                        0.0                         0
# plt49.run1 pat_3572                        0.0                         0
#
#                      rna_DDX3Y  rna_XIST rna_gender rna_sample_id_original  \
# rna project.run id
# plt1.run1 pat_88         844.0       8.0          M              Sample 49
# plt1.run1 pat_89         670.0       4.0          M              Sample 50
# ...                        ...       ...        ...                    ...
# plt49.run1 pat_3571        0.0       0.0          0                      0
# plt49.run1 pat_3572        0.0       0.0          0                      0
#
#                     rna_plate_id_original    filename rel_path  n_genes  \
# rna project.run id
# plt1.run1 pat_88                  Plate 1  matrix.mtx        .    23151
# plt1.run1 pat_89                  Plate 1  matrix.mtx        .    20116
# ...                                   ...         ...      ...      ...
# plt49.run1 pat_3571                     0  matrix.mtx        .    22116
# plt49.run1 pat_3572                     0  matrix.mtx        .    20727
#
#                      log1p_n_genes  total_counts  log1p_total_counts  \
# rna project.run id
# plt1.run1 pat_88         10.049836     4810335.0           15.386277
# plt1.run1 pat_89          9.909321     2155449.0           14.583510
# ...                            ...           ...                 ...
# plt49.run1 pat_3571      10.004102     3558559.0           15.084867
# plt49.run1 pat_3572       9.939241     2066628.0           14.541430
#
#                      total_counts_is_mito  log1p_total_counts_is_mito  \
# rna project.run id
# plt1.run1 pat_88                      0.0                         0.0
# plt1.run1 pat_89                      0.0                         0.0
# ...                                   ...                         ...
# plt49.run1 pat_3571                   0.0                         0.0
# plt49.run1 pat_3572                   0.0                         0.0
#
#                      pct_counts_is_mito  total_counts_is_ribo  \
# rna project.run id
# plt1.run1 pat_88                    0.0               52602.0
# plt1.run1 pat_89                    0.0               31098.0
# ...                                 ...                   ...
# plt49.run1 pat_3571                 0.0               45395.0
# plt49.run1 pat_3572                 0.0               36463.0
#
#                      log1p_total_counts_is_ribo  pct_counts_is_ribo  \
# rna project.run id
# plt1.run1 pat_88                      10.870528            1.093521
# plt1.run1 pat_89                      10.344931            1.442762
# ...                                         ...                 ...
# plt49.run1 pat_3571                   10.723179            1.275657
# plt49.run1 pat_3572                   10.504081            1.764372
#
#                      total_counts_is_gender  log1p_total_counts_is_gender  \
# rna project.run id
# plt1.run1 pat_88                   155239.0                     11.952727
# plt1.run1 pat_89                    71203.0                     11.173305
# ...                                     ...                           ...
# plt49.run1 pat_3571                118071.0                     11.679049
# plt49.run1 pat_3572                 68396.0                     11.133084
#
#                      pct_counts_is_gender   S_score  G2M_score phase leiden  \
# rna project.run id
# plt1.run1 pat_88                 3.227197  0.576068   0.352967     S      0
# plt1.run1 pat_89                 3.303395  1.189123   0.937463     S      0
# ...                                   ...       ...        ...   ...    ...
# plt49.run1 pat_3571              3.317944 -0.724729  -0.611794    G1      4
# plt49.run1 pat_3572              3.309546 -0.843705  -0.624322    G1      6
#
#                      LISI_score_X_pca  LISI_score_X_umap  phase_density  \
# rna project.run id
# plt1.run1 pat_88            10.143976           8.629763       0.920243
# plt1.run1 pat_89             5.626109           9.895226       0.897363
# ...                               ...                ...            ...
# plt49.run1 pat_3571          8.682547          10.933455       0.887389
# plt49.run1 pat_3572          9.820527          10.801533       0.748115
#
#                      meta_age_dec_density leiden_0.1 leiden_0.2 leiden_0.3  \
# rna project.run id
# plt1.run1 pat_88                 0.392842          1          1          1
# plt1.run1 pat_89                 0.401510          1          1          1
# ...                                   ...        ...        ...        ...
# plt49.run1 pat_3571              0.613038          1          1          1
# plt49.run1 pat_3572              0.716065          1          1          1
#
#                     leiden_0.4 leiden_0.5 leiden_0.6 leiden_0.7 leiden_0.8  \
# rna project.run id
# plt1.run1 pat_88             1          1          1          1          1
# plt1.run1 pat_89             1          1          1          1          1
# ...                        ...        ...        ...        ...        ...
# plt49.run1 pat_3571          3          3          2          2          7
# plt49.run1 pat_3572          3          3          5          5          7
#
#                     leiden_0.9 clustering
# rna project.run id
# plt1.run1 pat_88             1          1
# plt1.run1 pat_89             1          1
# ...                        ...        ...
# plt49.run1 pat_3571          5          2
# plt49.run1 pat_3572          7          5
#
# [3344 rows x 107 columns]

# %% [markdown]
# ---------

# %% [markdown]
# ## 4 - Select grouping
# <hr style="border:2px solid black"> </hr>
#
# Compute markers for all selected groupings and choose the optimal one based on the visualization. Ideally, markers should be only found within one group, causing the plot to show a "stair"-like pattern. The identified markers are typically used to assign cell types in downstream analysis.

# %% [markdown]
# <h1><center>⬐ Fill in input data here ⬎</center></h1>

# %%
# Column names of clustering columns
# Add all columns of interest
clustering_cols = ["leiden_0."] #, "leiden_0.2", "leiden_0.3", "leiden_0.4", "leiden_0.5", "leiden_0.6", "leiden_0.7", "leiden_0.8", "leiden_0.9"]

# Marker features

# Method for feature ranking
ranking_method = "t-test"
# Top n features to be reported, None for all features
top_n = None

# Marker feature filter

# Minimum fraction of cells in a group that must express a feature to be considered as a marker
min_in_group_fraction = 0.25
# Minimum foldchange (+/-) to be considered as a marker
min_fold_change = 0.5
# Maximum fraction of cells in other groups that must express a feature to be considered as a marker
max_out_group_fraction = 0.8

# Plotting
n_features_markerplot = 15  # number of features to show per group
marker_style = "dots"  # Either `dots` or `heatmap`.

# %% [markdown]
# ________

# %%
for clustering in clustering_cols:

    # Identify markers per cluster (adjust group fraction and fold change to filter features)
    tools.marker_genes.run_rank_genes(
        adata,
        clustering,
        min_in_group_fraction=min_in_group_fraction,
        min_fold_change=min_fold_change,
        max_out_group_fraction=max_out_group_fraction,
        n_genes=top_n,
        ranking_method=ranking_method,
        key_added=f"rank_feature_{clustering}"
    )

    # Plot dotplot of markers
    _ = pl.marker_genes.rank_genes_plot(
        adata,
        key=f"rank_feature_{clustering}_filtered",
        n_genes=n_features_markerplot,
        style=marker_style,
        title=clustering,
        save=f"marker_{marker_style}_{clustering}.pdf"
    )

# %% [markdown]
# <h1><center>⬐ Fill in input data here ⬎</center></h1>

# %%
# choose the final clustering (grouping)
final_clustering = "leiden_0.1"

# %%
for m_style in ["dots", "heatmap"]:
    # Plot dotplot of markers
    _ = pl.marker_genes.rank_genes_plot(
        adata,
        key=f"rank_feature_{final_clustering}_filtered",
        n_genes=n_features_markerplot,
        style=m_style,
        title=final_clustering,
        save=f"marker_{m_style}_{final_clustering}.pdf"
    )

# Write marker genes to table
marker_table = tools.marker_genes.get_rank_genes_tables(
    adata,
    out_group_fractions=True,
    key=f"rank_feature_{final_clustering}_filtered",
    save_excel=f"marker_feature_{final_clustering}.xlsx"
)

# %% [markdown]
# ---------

# %% [markdown]
# ## 5 - Feature accumulation
# <hr style="border:2px solid black"> </hr>
#
# This section shows the location of cells within the embedding that express features. Features are either the top markers of the respective group or a user-provided list of features.

# %% [markdown]
# <h1><center>⬐ Fill in input data here ⬎</center></h1>

# %%
# Top X marker to be plotted
n_marker = 5

# List of features additionally shown in the embedding.
custom_feat_list = []
# name of the feature group
fname = ""

# planet plot
# set the data which should be displayed on the x- and y-axis (adata.obs column names) to enable this plot
x = "phase"
y = final_clustering
log_scale=False

# embedding
embedding = "umap"  # Either umap or tsne
style = "hexbin"  # Either 'dots' to show all cells or 'hexbin' or 'density' for density approximations
binarize_threshold = 0.0  # threshold of a features expression that a cell must have to be shown in the binarized plot.
binarize_threshold_percentile = None # Percentile threshold of a features expression that a cell must have to be shown in the binarized plot. If this is set it takes precedence over binarize_threshold.

# %% [markdown]
# ______

# %% [markdown]
# ### 5.1 - Plot custom feature list
#
# Show where the selected features are expressed in the embedding.

# %%
if custom_feat_list:
    pl.embedding.plot_embedding(
        adata=adata,
        method=embedding,
        color=custom_feat_list,
        style=style,
        save=f"{embedding}_custom_list_expression.pdf",
        ncols=3
    )

# %% [markdown]
# Show the aggregated expression of the selected features.

# %%
if custom_feat_list:
    pl.embedding.agg_feature_embedding(
        adata=adata,
        features=custom_feat_list,
        fname=fname if fname else f"{', '.join(custom_feat_list)} mean expression",
        save=f"{embedding}_custom_list_aggr_expression.pdf"
    )

# %%
if custom_feat_list:
    _ = pl.embedding.feature_per_group(
        adata=adata,
        y=y,
        x=custom_feat_list,
        style=style,
        save=f"{embedding}_custom_list_with_groups.pdf",
        method=embedding
    )

# %%
if custom_feat_list:
    _ = pl.embedding.feature_per_group(
        adata=adata,
        y=y,
        x=custom_feat_list,
        binarize_threshold=binarize_threshold,
        binarize_percentile_threshold=binarize_threshold_percentile,
        style=style,
        save=f"{embedding}_custom_list_with_groups_binarized.pdf",
        method=embedding
    )

# %% [markdown]
# Show the expression of features split by x- and y-axis (e.g. clustering vs. cell-cycle). Each combination is further divided into a center dot showing the aggregation of the surrounding features.
#
# **Note: can display up to 6 surrounding features. Will use the first 6 if more are selected.**

# %%
if custom_feat_list and x and y:
    plot_vars = pl.planet_plot.planet_plot_anndata_preprocess(
        adata=adata,
        x_col=x,
        y_col=y,
        genes=custom_feat_list[:6]
    )
    
    pl.planet_plot.planet_plot_render(
        plot_vars,
        x_col=x,
        y_col=y,
        mode="planet",
        use_log_scale=log_scale,
        planet_columns=custom_feat_list[:6],
        color_schema="viridis"
    )

# %% [markdown]
# ---------

# %% [markdown]
# ### 5.2 - Plot cluster marker
# Show the top n markers expression next to their respective group. In the best case a marker is exclusively expressed within the cells that are assigned to the respective group.

# %%
_ = pl.embedding.feature_per_group(
    adata=adata,
    y=y,
    top_n=n_marker,
    marker_key=f"rank_feature_{final_clustering}_filtered",
    style=style,
    save=f"{embedding}_clustering_{y}_top_{n_marker}_markers.pdf",
    method=embedding
)

# %% [markdown]
# Show the top n markers expression binarized next to their respective group. This plot highlights where markers have a minimum expression level, making it easier to identify clusters with a high expression of the marker.

# %%
_ = pl.embedding.feature_per_group(
    adata=adata,
    y=y,
    top_n=n_marker,
    marker_key=f"rank_feature_{final_clustering}_filtered",
    binarize_threshold=binarize_threshold,
    binarize_percentile_threshold=binarize_threshold_percentile,
    style=style,
    save=f"{embedding}_clustering_{y}_top_{n_marker}_markers_binarized.pdf",
    method=embedding
)

# %% [markdown]
# ---------

# %% [markdown]
# ## 6 - Condition related markers
# Until this point markers were computed to identify differences between the previously created cluster groups. However, most experiments provide additional information (e.g. ill vs. healthy, wild-type vs. mutant, etc.). This section aims to use these conditions to identify changes within the above selected clusters.

# %%
with pd.option_context("display.max.rows", 5, "display.max.columns", None):
    display(adata.obs)

# %% [markdown]
# <h1><center>⬐ Fill in input data here ⬎</center></h1>

# %%
# Both variables expect a column name from above (adata.obs)
clustering_col = final_clustering  # the clustering e.g. the one chosen in the prior section
condition_col = "chamber"  # the condition used to find changes within each cluster

# %% [markdown]
# ____

# %% [markdown]
# The dataset is split on each cluster and a ranking is performed on each individual subset.

# %%
# split adata by group, then rank features on each
adata_cond = {}

for cluster in set(adata.obs[clustering_col]):
    print(f"Cluster {cluster}")
    adata_sub = adata[adata.obs[clustering_col] == cluster]

    # Check if sample count is sufficent
    value_counts = adata_sub.obs[condition_col].value_counts()
    insufficient_size = [i for i in value_counts.index if value_counts[i] == 1]
    if insufficient_size: 
        print(f"Removed conditions due to insufficent size {insufficient_size}")
        adata_sub = adata_sub[~adata_sub.obs[condition_col].isin(insufficient_size)]

    if len(set(adata_sub.obs[condition_col])) < 2:
        print(f"Skipped Cluster {cluster}")
        continue

    tools.marker_genes.run_rank_genes(
        adata_sub,
        condition_col,
        min_in_group_fraction=min_in_group_fraction,
        min_fold_change=min_fold_change,
        max_out_group_fraction=max_out_group_fraction,
        n_genes=top_n,
        ranking_method=ranking_method
    )
    
    adata_cond[cluster] = adata_sub

# %% [markdown]
# One dotplot per group (cluster) showing the top differential features.

# %%
for key, value in adata_cond.items():
    # Plot dotplot of markers
    _ = pl.marker_genes.rank_genes_plot(
        value,
        key=f"rank_genes_{condition_col}_filtered",
        n_genes=n_features_markerplot,
        style=marker_style,
        title=key,
        save=f"{marker_style}_{condition_col}_cluster_{key}.pdf"
    )

# %%
# write marker tables
for key, value in adata_cond.items():
    # Write marker genes to table
    deg_table = tools.marker_genes.get_rank_genes_tables(
        value,
        out_group_fractions=True,
        key=f"rank_genes_{condition_col}_filtered",
        save_excel=f"{condition_col}_cluster_{key}.xlsx"
    )

# %% [markdown]
# ---------

# %% [markdown]
#  ## 7 - Run DEseq2 between conditions/samples

# %% [markdown]
#  <h1><center>⬐ Fill in input data here ⬎</center></h1>

# %%
# Adjust which columns to use for DEseq2
sample_col = "sample"
condition_col = "chamber"

# %% [markdown]
# ___

# %%
# Normalize raw counts across cells
d = sc.pp.normalize_total(adata, layer="raw", inplace=False) # returns a dict
adata.layers["raw_norm"] = d["X"]
adata.layers["raw_norm"] = adata.layers["raw_norm"].ceil().astype(int)

# %%
# Run DEseq2import numpy as np
deseq_table = tools.marker_genes.run_deseq2(adata, sample_col, condition_col, layer="raw_norm")

# %% [markdown]
# The DEseq2 result table (below) shows the top 10 differential features sorted after the p-value of the first two conditions.
#
# | Column | Description |
# |--------|-------------|
# |`[condition]_mean`|The mean expression of the respective feature within the given condition.|
# |`[condition 1]/[condition 2]_log2FoldChange`|Log2 of the quotient of the two conditions mean expression. Values `>0` can be interpreted as "more expression in 'condition 1'" and `<0` as "more expression in 'condition 2'".|
# |`[condition 1]/[condition 2]_pvalue`|The convidence if a feature is expressed differentially between the two conditions. Closer to zero = better. `<=0.05` is typically considered significant.|
# |`[condition 1]/[condition 2]_padj`|The p-value (see above) adjusted for the number of tests (here features).|
# |`[sample][condition]`|The mean feature expression within the respective sample and condition.|
# |`baseMean`|The mean expression over each sample split by condition (see above).|

# %%
with pd.option_context("display.max.rows", 10, "display.max.columns", None):
    display(deseq_table.head(10))
print(f"{len(deseq_table)} rows x {len(deseq_table.columns)} columns")

# %%
deseq_table.to_excel(f"{sctoolbox.settings.table_dir}/DEseq_{sample_col}_vs_{condition_col}.xlsx")

# %% [markdown]
# ---------

# %% [markdown]
# ## 8 - Save adata

# %%
utils.adata.save_h5ad(adata, "anndata_marker.h5ad")
